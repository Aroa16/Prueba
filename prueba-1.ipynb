# %%
import pandas as pd

# %%
exepectancy = pd.read_csv('https://raw.githubusercontent.com/Aroa16/Prueba/main/example_Solutions%20-%20example_events_file%20-%20example_events_file.csv')

# %%
exepectancy.head()
# Out:
#                email           email.1          email.2             phone  \
# 0  elizabetho@fb.com     olsene@fb.com    eolsen@fb.com  1-(650)-561-5622
# 1     andrewj@fb.com   jamisona@fb.com  ajamison@fb.com  1-(212) 736-3100
# 2   margaretj@fb.com   johnsonm@fb.com  mjohnson@fb.com  1-(323) 857-6000
# 3       johnd@fb.com       doej@fb.com      jdoe@fb.com  1-(312) 443-3600
# 4       marks@fb.com  smithmark@fb.com    msmith@fb.com  +44 303 123 7300
#
#                                   madid              Name    zip code country  \
# 0  aece52e7-03ee-455a-b3c4-e57283966239   Elizabeth Olsen       94046      US
# 1  BEBE52E7-03EE-455A-B3C4-E57283966239    Andrew Jamison       10118      US
# 2  adbe52e7-03ee-455a-b3c4-e57283966239  Margaret Johnson  90001-4656      US
# 3  AEBE52E7-03EE-455A-B3C4-E57283966239          John Doe       60603      US
# 4  AEBD52E7-03EE-455A-B3C4-E57283966239        Mark Smith    SW1A 1AA      GB
#
#    gender    action Checkout_time    Price
# ...

# %%
exepectancy.loc[:, ['email', 'phone', 'Name','country','gender','Price']]
# Out:
#                email             phone              Name country  gender  \
# 0  elizabetho@fb.com  1-(650)-561-5622   Elizabeth Olsen      US  Female
# 1     andrewj@fb.com  1-(212) 736-3100    Andrew Jamison      US    Male
# 2   margaretj@fb.com  1-(323) 857-6000  Margaret Johnson      US  Female
# 3       johnd@fb.com  1-(312) 443-3600          John Doe      US    Male
# 4       marks@fb.com  +44 303 123 7300        Mark Smith      GB    Male
# 5      jamesm@fb.com  +44 20 7219 4272  James McLaughlin      GB    Male
# 6      pauloa@fb.com  +55 21 3938-6900  Paulo Alessandro      BR    Male
# 7      mariel@fb.com  +33 892 70 12 39     Marie Laurent      FR  Female
# 8     thomasd@fb.com  +33 892 70 12 39     Thomas Dubois      FR    Male
# 9  elizabetho@fb.com  1-(650)-561-5622   Elizabeth Olsen      US  Female
#
#      Price
# 0   $15,00
# 1  15,00 €
# 2   $15,00
# 3   $15,00
# 4  10,00 €
# 5  10,00 €
# 6  10,00 €
# 7  10,00 €
# 8  10,00 €
# 9   $15,00

# %%
lista=exepectancy.loc[:, ['email', 'phone', 'Name','country','gender','Price']]

# %%
lista.head()
# Out:
#                email             phone              Name country  gender  \
# 0  elizabetho@fb.com  1-(650)-561-5622   Elizabeth Olsen      US  Female
# 1     andrewj@fb.com  1-(212) 736-3100    Andrew Jamison      US    Male
# 2   margaretj@fb.com  1-(323) 857-6000  Margaret Johnson      US  Female
# 3       johnd@fb.com  1-(312) 443-3600          John Doe      US    Male
# 4       marks@fb.com  +44 303 123 7300        Mark Smith      GB    Male
#
#      Price
# 0   $15,00
# 1  15,00 €
# 2   $15,00
# 3   $15,00
# 4  10,00 €

# %%
lista.to_csv("listadeprueba.csv",index=False)
